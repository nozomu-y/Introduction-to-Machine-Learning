# %% [markdown]
# # Visualizing a decision tree
# https://www.youtube.com/watch?v=tNa99PG8hR8

# %% [markdown]
# ## Import dataset

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn import tree

# %%
iris = load_iris()
print(iris.feature_names)
print(iris.target_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# From the features, we want to guess what the label is.
# In order to do this, we'll need to train a classifier using traning dataset.
# This is called *Supervised Learning*.

# %% [markdown]
# ### Split data into training data and testing data
# In order to test the classifier's accuracy, we need to split data into *training data* and *testing data*.

# %%
test_idx = [0, 50, 100]

# training data
train_target = np.delete(iris.target, test_idx)
train_data = np.delete(iris.data, test_idx, axis=0)

# testing data
test_target = iris.target[test_idx]
test_data = iris.data[test_idx]

# %% [markdown]
# ## Train a classifier

# %%
clf = tree.DecisionTreeClassifier()
clf.fit(train_data, train_target)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Predict label for new features

# %%
print(test_target)
print(clf.predict(test_data))
# Out:
# [0 1 2]
# [0 1 2]

# %% [markdown]
# ## Visualize the tree

# %%
from six import StringIO
import pydot

dot_data = StringIO()
tree.export_graphviz(clf, 
                    out_file=dot_data, 
                    feature_names=iris.feature_names,
                    class_names=iris.target_names,
                    filled=True,
                    rounded=True,
                    impurity=False
                    )
graph, = pydot.graph_from_dot_data(dot_data.getvalue())
graph.write_pdf("iris.pdf")

# %% [markdown]
# By selecting better features, you can build a better tree.
# Choosing good features is one of the most important jobs.
